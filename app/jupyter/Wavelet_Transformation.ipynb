# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

import sys
sys.path.append('../analysis/')
from csv_to_pandas import csv_into_dict_of_data

import sys
sys.path.append('../analysis/')
from wavelet_transformation import csv_into_wavelet_transformed_dict_of_dataframe

import sys
sys.path.append('../analysis/')
from other_function import getDuplicateColumns

df_key = 'dns'
wavelet = 'db1'

# %%
df_dict = csv_into_dict_of_data(training_dataset)
df = df_dict[df_key]

# %%
df.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic @ 15 minute interval'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'dns traffic @ 15 minute interval')

# %%
dups = getDuplicateColumns(df)
dups
# Out:
# []

# %%
training_dataset = "../../csv/training_dataset"
df_dict_transformed1 = csv_into_wavelet_transformed_dict_of_dataframe(wavelet, 1, training_dataset)
df1 = df_dict_transformed1[df_key]
df1.head()
# Out:
#      2019-01-26    2018-11-16   2018-11-15    2019-01-24   2018-10-24  \
# 0  15045.818090  10349.921956  9632.915680  14111.022925  9609.581156
# 1  15463.718198   8193.246274  6634.075821  13389.066902  6293.957459
# 2  14954.601315   8400.428560  8434.369686  14558.621518  7682.715178
# 3  11090.969863   8667.007817  6990.457639  13212.997313  6716.807314
# 4  10402.247858   8383.457998  7327.040467  12633.169753  7501.695842
#
#     2018-11-06    2018-12-18    2019-01-06  2018-09-09   2018-11-11  \
# 0  8522.050927  13662.717226  10455.987973  360.624458  7416.843028
# 1  5579.779610  12843.180467   9796.964453  349.310750  6013.943174
# 2  6303.856954  13888.284289  11813.632993  356.381818  5645.540541
# 3  7222.388663   8835.299231  10274.261531  345.068109  5693.623802
# 4  6607.912870   8220.823438  10637.714416  354.260497  5201.477482
#
#       ...         2019-01-04   2018-10-22   2018-10-30  2018-09-12  \
# 0     ...       10956.619574  8170.618857  9367.043530   82.024387
# 1     ...       10885.908896  5736.757316  6675.795121   82.731493
# 2     ...       11790.298470  7403.407999  6739.434731   78.488853
# 3     ...        9828.077152  5715.544112  6265.673188   76.367532
# 4     ...       10227.592483  6247.995519  6998.942920   86.974134
#
#      2018-09-23   2018-11-03    2018-10-19    2018-09-20    2019-01-30  \
# 0  12048.392445  9084.200818  10610.137252  12255.574732  13936.367550
# 1   9931.314742  7709.585235   7071.774919  10175.973688  12246.382343
# 2  10289.817880  6945.909912   7310.069904  10192.237144  12442.958029
# 3  10613.672786  6371.032098   6857.521564  11367.448614  14086.274188
# 4  10156.881805  6757.819508   7362.395806  10917.728702  11023.087612
#
#     2018-11-23
# 0  9407.348617
# 1  6971.365756
# 2  6224.660995
# 3  7903.332493
# 4  6716.100208
#
# [5 rows x 147 columns]

# %%
df1.shape
# Out:
# (48, 147)

# %%
df1.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic after '+ wavelet + ' transformation'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'dns traffic after db1 transformation')

# %%
dups = getDuplicateColumns(df1)
dups
# Out:
# []

# %%
df_dict_transformed2 = csv_into_wavelet_transformed_dict_of_dataframe(wavelet, 2, training_dataset)
df2 = df_dict_transformed2[df_key]
df2.shape
# Out:
# (24, 145)

# %%
dups2 = getDuplicateColumns(df2)
dups2
# Out:
# []

# %%
df2.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic after 2 levels of '+ wavelet + ' transformation'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'snmp traffic after 2 levels of haar transformation')

# %%
df_dict_transformed6 = csv_into_wavelet_transformed_dict_of_dataframe(wavelet, 6, training_dataset)
df6 = df_dict_transformed6[df_key]
df6.shape
# Out:
# (2, 145)

# %%
dups6 = getDuplicateColumns(df6)
dups6
# Out:
# []
