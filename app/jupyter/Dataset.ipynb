# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

import sys
sys.path.append('../analysis/')
from csv_to_pandas import csv_into_dict_of_data
from plot_graph import remove_zero_columns

# %%
df_dict = csv_into_dict_of_data(training_dataset)
df_dict = remove_zero_columns(df_dict)
df_dict.keys()

# %%
df = df_dict['dns']
df = df.reindex(sorted(df.columns), axis = 1)
df.head()
# Out:
#           2018-09-07  2018-09-08  2018-09-09  2018-09-10  2018-09-11  \
# Time
# 00:00:00         0.0          62       243.0         0.0          57
# 00:15:00         0.0          52       267.0         0.0          69
# 00:30:00         0.0          56       244.0         0.0          60
# 00:45:00         0.0          64       250.0         0.0          52
# 01:00:00         0.0          64       244.0         0.0          52
#
#           2018-09-12  2018-09-13  2018-09-14  2018-09-15  2018-09-16  \
# Time
# 00:00:00          56          65          57          53          62
# 00:15:00          60          63          54          57          54
# 00:30:00          51          51          60          51          54
# 00:45:00          66          51          63          69          60
# 01:00:00          51          57          51          54          51
#
#              ...      2019-01-22  2019-01-23  2019-01-24  2019-01-25  \
# Time         ...
# 00:00:00     ...            7011        7602        9287       10654
# 00:15:00     ...            7500        8071       10669       10280
# 00:30:00     ...            6090        6785        8978        8571
# 00:45:00     ...            7040        8617        9957        9663
# 01:00:00     ...            6203        6074        8611        9411
#
#           2019-01-26  2019-01-27  2019-01-28  2019-01-29  2019-01-30  \
# Time
# 00:00:00       10512        6440        9573        9973        9551
# 00:15:00       10766        6756        8666        8482       10158
# 00:30:00       10142        6368        8017        7933        9799
# 00:45:00       11727        7128        8686        8388        7520
# 01:00:00        9984        6499        7576        8559        8888
#
#           2019-01-31
# Time
# 00:00:00        7801
# 00:15:00        7956
# 00:30:00        7991
# 00:45:00       10605
# 01:00:00        8621
#
# [5 rows x 147 columns]

# %%
df.shape
# Out:
# (96, 147)

# %%
df.plot(legend = False, figsize = (20, 10) )
# df.plot(legend = True, figsize = (20, 10) )
plt.title('DNS Traffic @ 15 minute interval', fontsize=20)
# Out:
# Text(0.5, 1.0, 'DNS Traffic @ 15 minute interval')
