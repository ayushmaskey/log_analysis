# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

import sys
sys.path.append('../analysis/')
from csv_to_pandas import csv_into_dict_of_data
from wavelet_transformation import csv_into_wavelet_transformed_dict_of_dataframe

from kmeans_elbow import find_k_for_KMeans_elbow_method_score as elbow
from constants import start, end, training_dataset, plot_save_dir, wavelet_to_use

import sys
sys.path.append('../elastic/')
from es_to_csv import dir_exists, file_exists

# %%
df_dict = csv_into_dict_of_data(training_dataset)
df_dict.keys()
# Out:
# dict_keys(['conn', 'dhcp', 'weird', 'http', 'total', 'snmp', 'external', 'dns', 'files'])

# %%
df = df_dict['dns']
df.head()
# Out:
#           2019-01-26  2018-11-16  2018-11-15  2019-01-24  2018-10-24  \
# Time
# 00:00:00       10512        9331        8384        9287        8602
# 00:15:00       10766        5306        5239       10669        4988
# 00:30:00       10142        5842        4929        8978        4550
# 00:45:00       11727        5745        4453        9957        4351
# 01:00:00        9984        6213        6575        8611        4908
#
#           2018-11-06  2018-12-18  2019-01-06  2018-09-09  2018-11-11  \
# Time
# 00:00:00        7896        9810        7745       243.0        7024
# 00:15:00        4156        9512        7042       267.0        3465
# 00:30:00        4257        9167        6640       244.0        3935
# 00:45:00        3634        8996        7215       250.0        4570
# 01:00:00        4666       10871        6165       244.0        4494
#
#              ...      2019-01-04  2018-10-22  2018-10-30  2018-09-12  \
# Time         ...
# 00:00:00     ...            8053        7325        7941          56
# 00:15:00     ...            7442        4230        5306          60
# 00:30:00     ...            6942        4041        4720          51
# 00:45:00     ...            8453        4072        4721          66
# 01:00:00     ...            7443        5937        4533          51
#
#           2018-09-23  2018-11-03  2018-10-19  2018-09-20  2019-01-30  \
# Time
# 00:00:00       10251        8457        9843     10381.0        9551
# 00:15:00        6788        4390        5162      6951.0       10158
# 00:30:00        6900        6128        5026      7555.0        9799
# 00:45:00        7145        4775        4975      6836.0        7520
# 01:00:00        8014        5263        5342      7237.0        8888
#
#           2018-11-23
# Time
# 00:00:00        8242
# 00:15:00        5062
# 00:30:00        5471
# 00:45:00        4388
# 01:00:00        4629
#
# [5 rows x 147 columns]

# %%
df.plot(legend = False, figsize=(30, 15) )
