# %%
import pandas as pd

import sys
sys.path.append('../analysis/')
from csv_to_pandas import dictionary_of_dataframes

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_dict = dictionary_of_dataframes()

# %%
key_list = list(df_dict.keys() )
key_list
# Out:
# ['dhcp', 'snmp', 'conn', 'files', 'external', 'total', 'http', 'dns', 'weird']

# %%
total = df_dict['total']
total.plot(legend = False)

# %%
total.head(5)
# Out:
#           2018-09-26  2018-09-27  2018-09-05  2018-09-10  2018-10-12  \
# Time
# 00:00:00      490736      446421      490012         410      530079
# 00:15:00      360455      346632      374959         370      343955
# 00:30:00      454614      469603      528562         471      461657
# 00:45:00      364866      350079      431634         484      371914
# 01:00:00      405733      394998      398748         422      440034
#
#           2018-09-02  2018-09-07  2018-09-23  2018-10-03  2018-09-20  \
# Time
# 00:00:00          51      406386      499596      545875      490823
# 00:15:00          49      413081      358352      424323      357905
# 00:30:00          51      524829      473107      544576      479952
# 00:45:00          51      318486      357498      425599      352055
# 01:00:00          51      328340      430245      445844      383647
#
#              ...      2018-08-30  2018-09-08  2018-10-13  2018-09-06  \
# Time         ...
# 00:00:00     ...             0.0      475193      556283      494306
# 00:15:00     ...             0.0      384422      391226      466545
# 00:30:00     ...             0.0      483484      496872      476827
# 00:45:00     ...             0.0      378206      370888      372172
# 01:00:00     ...             0.0      409269      448285      398848
#
#           2018-09-12  2018-10-08  2018-09-24  2018-10-09  2018-10-06  \
# Time
# 00:00:00      420627      525521      439340      560674      484280
# 00:15:00      547050      377730      331139      385270      325604
# 00:30:00      418813      431554      452539      505149      455687
# 00:45:00      330620      305317      434024      523883      330354
# 01:00:00      347797      340828      390323      467984      390255
#
#           2018-09-17
# Time
# 00:00:00      379209
# 00:15:00      303384
# 00:30:00      402286
# 00:45:00      300850
# 01:00:00      321255
#
# [5 rows x 52 columns]
