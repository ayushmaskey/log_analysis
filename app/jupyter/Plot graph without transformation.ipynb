# %%
import pandas as pd

import sys
sys.path.append('../analysis/')
from csv_to_pandas import loop_over_directory_structure_return_pandas_df

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_path = "../../csv"
df_dict = loop_over_directory_structure_return_pandas_df(csv_path)

# %%
key_list = list(df_dict.keys() )
key_list
# Out:
# ['total', 'snmp', 'external', 'http', 'dhcp', 'files', 'dns', 'weird', 'conn']

# %%
total = df_dict['total']
total.plot(legend = False)

# %%
snmp = df_dict['snmp']
snmp.plot(legend = False)

# %%
external = df_dict['external']
external.plot(legend = False)

# %%
http = df_dict['http']
http.plot(legend = False)

# %%
dhcp = df_dict['dhcp']
dhcp.plot(legend = False)

# %%
dns = df_dict['dns']
dns.plot(legend = False)

# %%
files = df_dict['files']
files.plot(legend = False)

# %%
weird = df_dict['weird']
weird.plot(legend = False)

# %%
conn = df_dict['conn']
conn.plot(legend = False)
