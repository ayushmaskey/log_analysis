# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

import sys
sys.path.append('../analysis/')
from csv_to_pandas import csv_into_dict_of_data
from wavelet_transformation import csv_into_wavelet_transformed_dict_of_dataframe
from other_function import getDuplicateColumns

training_dataset = "../../csv/training_dataset"
testing_dataset = "../../csv/testing_dataset"
df_key = 'snmp'
wavelet = 'db1'

# %%
df_dict = csv_into_dict_of_data(training_dataset)
df = df_dict[df_key]

# %%
df.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic @ 15 minute interval'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'snmp traffic @ 15 minute interval')

# %%
dups = getDuplicateColumns(df)
dups
# Out:
# []

# %%
level = 1
training_dataset = "../../csv/training_dataset"
df_dict_transformed1 = csv_into_wavelet_transformed_dict_of_dataframe(wavelet, level, training_dataset)
df1 = df_dict_transformed1[df_key]
df1.head()
# Out:
#     2018-12-19   2018-11-26   2018-12-18   2019-01-30   2019-01-21  \
# 0  2537.099131  4190.314785  2510.936180  4107.583292  2340.523446
# 1  2397.799095  2386.485387  2438.811288  2388.606707  2126.977198
# 2  2409.112804  2428.911793  2371.636144  2349.715834  2145.361974
# 3  2434.568648  2392.142241  2346.887407  2349.008727  2242.235603
# 4  2412.648337  2386.485387  2339.816339  2385.778280  2183.545740
#
#     2019-01-28   2018-11-12   2018-11-11   2018-09-23   2018-11-02  \
# 0  2423.254939  4308.401618  4192.436106  1858.276621  4188.900572
# 1  2330.623951  2400.627522  2399.213309  2796.607320  2396.384881
# 2  2281.833583  2419.719405  2439.518395  2621.951945  2395.677775
# 3  2320.724456  2407.698590  2416.890978  2588.010819  2388.606707
# 4  2288.197544  2443.053929  2407.698590  2613.466663  2406.284376
#
#       ...        2018-12-05   2018-10-23  2018-09-08   2018-10-28  \
# 0     ...       4157.080767  4345.171170    7.778175  4446.994547
# 1     ...       2457.903171  2550.534160    0.000000  2655.185963
# 2     ...       2426.083366  2555.483907    0.000000  2649.529109
# 3     ...       2352.544261  2565.383402    0.000000  2637.508294
# 4     ...       2358.201115  2561.140761    0.000000  2793.071786
#
#     2019-01-16    2018-12-07   2018-11-03   2018-10-18   2018-10-10  \
# 0  2523.664102  76250.152642  4191.021892  4431.438198  4414.467635
# 1  2363.857970  78007.312994  2389.313814  2602.152955  2643.165148
# 2  2385.778280  71036.654345  2412.648337  2651.650429  2643.165148
# 3  2099.400033  72077.515527  2385.071173  2611.345343  2629.730119
# 4  2846.104794  75997.715522  2387.192493  2621.244838  2616.295090
#
#     2018-11-15
# 0  4208.699562
# 1  2426.083366
# 2  2432.447327
# 3  2449.417890
# 4  2416.890978
#
# [5 rows x 145 columns]

# %%
df1.shape
# Out:
# (48, 145)

# %%
df1.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic after '+ str(level) + ' ' + wavelet + ' transformation'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'snmp traffic after 1 db1 transformation')

# %%
dups = getDuplicateColumns(df1)
dups
# Out:
# []

# %%
level = 2
df_dict_transformed2 = csv_into_wavelet_transformed_dict_of_dataframe(wavelet, level, training_dataset)
df2 = df_dict_transformed2[df_key]
df2.shape
# Out:
# (24, 145)

# %%
dups2 = getDuplicateColumns(df2)
dups2
# Out:
# []

# %%
df2.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic after '+ str(level) + ' ' + wavelet + ' transformation'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'snmp traffic after 2 db1 transformation')

# %%
level = 6
df_dict_transformed6 = csv_into_wavelet_transformed_dict_of_dataframe(wavelet, level, training_dataset)
df6 = df_dict_transformed6[df_key]
df6.shape
# Out:
# (2, 145)

# %%
dups6 = getDuplicateColumns(df6)
dups6
# Out:
# []

# %%
df2.plot(legend = False, figsize = (20, 10) )
title = df_key + ' traffic after '+ str(level) + ' ' + wavelet + ' transformation'
plt.title(title, fontsize=20)
# Out:
# Text(0.5, 1.0, 'snmp traffic after 6 db1 transformation')
